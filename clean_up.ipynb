# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 100)

DATA_PATH = "/Users/plon/НедвижкаДанные/Moscow_cleaned.csv"

df = pd.read_csv(DATA_PATH)

df.shape
# Out:
# (2044405, 14)
